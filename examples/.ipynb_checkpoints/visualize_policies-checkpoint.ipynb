# %%
import pprint
from graphviz import Digraph
from pymongo import MongoClient

# %%
client = MongoClient('localhost')
db = client["IDM"]

# %%
policy = db.policies.find_one({"_id": "Acc1_Pol1"})

# %%
pprint.pprint(policy)
# Out:
# {'_id': 'Acc1_Pol1',
#  'acc_id': 'Acc_1',
#  'covered_perils': ['EQ', 'FL', 'WS', 'FI'],
#  'expiration_date': datetime.datetime(2018, 12, 31, 0, 0),
#  'inception_date': datetime.datetime(2018, 1, 1, 0, 0),
#  'layers': [{'covers': ['InsObj_1_2'],
#              'feeds_into': ['layer_2_1_1'],
#              'layer_id': 'layer_1_2_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_4'],
#              'feeds_into': ['layer_2_1_1'],
#              'layer_id': 'layer_1_4_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_5'],
#              'feeds_into': ['layer_2_1_1'],
#              'layer_id': 'layer_1_5_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_7'],
#              'feeds_into': ['layer_2_1_1'],
#              'layer_id': 'layer_1_7_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_8'],
#              'feeds_into': ['layer_2_1_1'],
#              'layer_id': 'layer_1_8_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_9'],
#              'feeds_into': ['layer_2_1_1'],
#              'layer_id': 'layer_1_9_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_10'],
#              'feeds_into': ['layer_2_1_1'],
#              'layer_id': 'layer_1_10_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_11'],
#              'feeds_into': ['layer_2_1_1'],
#              'layer_id': 'layer_1_11_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_12'],
#              'feeds_into': ['layer_2_1_1'],
#              'layer_id': 'layer_1_12_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_13'],
#              'feeds_into': ['layer_2_1_1'],
#              'layer_id': 'layer_1_13_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_14'],
#              'feeds_into': ['layer_2_1_1'],
#              'layer_id': 'layer_1_14_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_15'],
#              'feeds_into': ['layer_2_1_1'],
#              'layer_id': 'layer_1_15_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_16'],
#              'feeds_into': ['layer_2_1_1'],
#              'layer_id': 'layer_1_16_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_17'],
#              'feeds_into': ['layer_2_1_1'],
#              'layer_id': 'layer_1_17_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_18'],
#              'feeds_into': ['layer_2_1_1'],
#              'layer_id': 'layer_1_18_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_19'],
#              'feeds_into': ['layer_2_1_1'],
#              'layer_id': 'layer_1_19_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_20'],
#              'feeds_into': ['layer_2_1_1'],
#              'layer_id': 'layer_1_20_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_21'],
#              'feeds_into': ['layer_2_2_1'],
#              'layer_id': 'layer_1_21_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_22'],
#              'feeds_into': ['layer_2_2_1'],
#              'layer_id': 'layer_1_22_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_23'],
#              'feeds_into': ['layer_2_2_1'],
#              'layer_id': 'layer_1_23_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_24'],
#              'feeds_into': ['layer_2_2_1'],
#              'layer_id': 'layer_1_24_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_25'],
#              'feeds_into': ['layer_2_2_1'],
#              'layer_id': 'layer_1_25_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_26'],
#              'feeds_into': ['layer_2_2_1'],
#              'layer_id': 'layer_1_26_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_28'],
#              'feeds_into': ['layer_2_2_1'],
#              'layer_id': 'layer_1_28_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_29'],
#              'feeds_into': ['layer_2_2_1'],
#              'layer_id': 'layer_1_29_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_30'],
#              'feeds_into': ['layer_2_2_1'],
#              'layer_id': 'layer_1_30_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_31'],
#              'feeds_into': ['layer_2_2_1'],
#              'layer_id': 'layer_1_31_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_32'],
#              'feeds_into': ['layer_2_2_1'],
#              'layer_id': 'layer_1_32_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_34'],
#              'feeds_into': ['layer_2_2_1'],
#              'layer_id': 'layer_1_34_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_35'],
#              'feeds_into': ['layer_2_2_1'],
#              'layer_id': 'layer_1_35_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_36'],
#              'feeds_into': ['layer_2_2_1'],
#              'layer_id': 'layer_1_36_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_37'],
#              'feeds_into': ['layer_2_2_1'],
#              'layer_id': 'layer_1_37_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_38'],
#              'feeds_into': ['layer_2_2_1'],
#              'layer_id': 'layer_1_38_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_39'],
#              'feeds_into': ['layer_2_2_1'],
#              'layer_id': 'layer_1_39_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_40'],
#              'feeds_into': ['layer_2_2_1'],
#              'layer_id': 'layer_1_40_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_41'],
#              'feeds_into': ['layer_2_3_1'],
#              'layer_id': 'layer_1_41_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_42'],
#              'feeds_into': ['layer_2_3_1'],
#              'layer_id': 'layer_1_42_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_43'],
#              'feeds_into': ['layer_2_3_1'],
#              'layer_id': 'layer_1_43_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_44'],
#              'feeds_into': ['layer_2_3_1'],
#              'layer_id': 'layer_1_44_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_45'],
#              'feeds_into': ['layer_2_3_1'],
#              'layer_id': 'layer_1_45_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_46'],
#              'feeds_into': ['layer_2_3_1'],
#              'layer_id': 'layer_1_46_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_47'],
#              'feeds_into': ['layer_2_3_1'],
#              'layer_id': 'layer_1_47_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_48'],
#              'feeds_into': ['layer_2_3_1'],
#              'layer_id': 'layer_1_48_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_49'],
#              'feeds_into': ['layer_2_3_1'],
#              'layer_id': 'layer_1_49_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_50'],
#              'feeds_into': ['layer_2_3_1'],
#              'layer_id': 'layer_1_50_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_51'],
#              'feeds_into': ['layer_2_3_1'],
#              'layer_id': 'layer_1_51_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_52'],
#              'feeds_into': ['layer_2_3_1'],
#              'layer_id': 'layer_1_52_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_53'],
#              'feeds_into': ['layer_2_3_1'],
#              'layer_id': 'layer_1_53_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_54'],
#              'feeds_into': ['layer_2_3_1'],
#              'layer_id': 'layer_1_54_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_55'],
#              'feeds_into': ['layer_2_3_1'],
#              'layer_id': 'layer_1_55_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_56'],
#              'feeds_into': ['layer_2_3_1'],
#              'layer_id': 'layer_1_56_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_57'],
#              'feeds_into': ['layer_2_3_1'],
#              'layer_id': 'layer_1_57_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_58'],
#              'feeds_into': ['layer_2_3_1'],
#              'layer_id': 'layer_1_58_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_59'],
#              'feeds_into': ['layer_2_3_1'],
#              'layer_id': 'layer_1_59_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_60'],
#              'feeds_into': ['layer_2_3_1'],
#              'layer_id': 'layer_1_60_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_61'],
#              'feeds_into': ['layer_2_4_1'],
#              'layer_id': 'layer_1_61_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_62'],
#              'feeds_into': ['layer_2_4_1'],
#              'layer_id': 'layer_1_62_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_63'],
#              'feeds_into': ['layer_2_4_1'],
#              'layer_id': 'layer_1_63_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_64'],
#              'feeds_into': ['layer_2_4_1'],
#              'layer_id': 'layer_1_64_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_65'],
#              'feeds_into': ['layer_2_4_1'],
#              'layer_id': 'layer_1_65_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_66'],
#              'feeds_into': ['layer_2_4_1'],
#              'layer_id': 'layer_1_66_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_67'],
#              'feeds_into': ['layer_2_4_1'],
#              'layer_id': 'layer_1_67_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_68'],
#              'feeds_into': ['layer_2_4_1'],
#              'layer_id': 'layer_1_68_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_69'],
#              'feeds_into': ['layer_2_4_1'],
#              'layer_id': 'layer_1_69_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_70'],
#              'feeds_into': ['layer_2_4_1'],
#              'layer_id': 'layer_1_70_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_71'],
#              'feeds_into': ['layer_2_4_1'],
#              'layer_id': 'layer_1_71_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_72'],
#              'feeds_into': ['layer_2_4_1'],
#              'layer_id': 'layer_1_72_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_73'],
#              'feeds_into': ['layer_2_4_1'],
#              'layer_id': 'layer_1_73_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_74'],
#              'feeds_into': ['layer_2_4_1'],
#              'layer_id': 'layer_1_74_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_75'],
#              'feeds_into': ['layer_2_4_1'],
#              'layer_id': 'layer_1_75_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_76'],
#              'feeds_into': ['layer_2_4_1'],
#              'layer_id': 'layer_1_76_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_77'],
#              'feeds_into': ['layer_2_4_1'],
#              'layer_id': 'layer_1_77_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_78'],
#              'feeds_into': ['layer_2_4_1'],
#              'layer_id': 'layer_1_78_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_79'],
#              'feeds_into': ['layer_2_4_1'],
#              'layer_id': 'layer_1_79_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_80'],
#              'feeds_into': ['layer_2_4_1'],
#              'layer_id': 'layer_1_80_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_81'],
#              'feeds_into': ['layer_2_5_1'],
#              'layer_id': 'layer_1_81_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_82'],
#              'feeds_into': ['layer_2_5_1'],
#              'layer_id': 'layer_1_82_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_83'],
#              'feeds_into': ['layer_2_5_1'],
#              'layer_id': 'layer_1_83_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_84'],
#              'feeds_into': ['layer_2_5_1'],
#              'layer_id': 'layer_1_84_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_86'],
#              'feeds_into': ['layer_2_5_1'],
#              'layer_id': 'layer_1_86_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['InsObj_1_87'],
#              'feeds_into': ['layer_2_5_1'],
#              'layer_id': 'layer_1_87_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50.0}]}},
#             {'covers': ['layer_1_2_1',
#                         'layer_1_4_1',
#                         'layer_1_5_1',
#                         'layer_1_7_1',
#                         'layer_1_8_1',
#                         'layer_1_9_1',
#                         'layer_1_10_1',
#                         'layer_1_11_1',
#                         'layer_1_12_1',
#                         'layer_1_13_1',
#                         'layer_1_14_1',
#                         'layer_1_15_1',
#                         'layer_1_16_1',
#                         'layer_1_17_1',
#                         'layer_1_18_1',
#                         'layer_1_19_1',
#                         'layer_1_20_1',
#                         'InsObj_1_1',
#                         'InsObj_1_3',
#                         'InsObj_1_6'],
#              'feeds_into': ['layer_3_1_1', 'layer_3_1_2'],
#              'layer_id': 'layer_2_1_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 10000.0}],
#                        'limit': [{'type': 'fixed amount',
#                                   'value': 1000000.0}]}},
#             {'covers': ['layer_1_21_1',
#                         'layer_1_22_1',
#                         'layer_1_23_1',
#                         'layer_1_24_1',
#                         'layer_1_25_1',
#                         'layer_1_26_1',
#                         'layer_1_28_1',
#                         'layer_1_29_1',
#                         'layer_1_30_1',
#                         'layer_1_31_1',
#                         'layer_1_32_1',
#                         'layer_1_34_1',
#                         'layer_1_35_1',
#                         'layer_1_36_1',
#                         'layer_1_37_1',
#                         'layer_1_38_1',
#                         'layer_1_39_1',
#                         'layer_1_40_1',
#                         'InsObj_1_27',
#                         'InsObj_1_33'],
#              'feeds_into': ['layer_3_1_1', 'layer_3_1_2'],
#              'layer_id': 'layer_2_2_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 20000.0}],
#                        'limit': [{'type': 'fixed amount',
#                                   'value': 2000000.0}]}},
#             {'covers': ['layer_1_41_1',
#                         'layer_1_42_1',
#                         'layer_1_43_1',
#                         'layer_1_44_1',
#                         'layer_1_45_1',
#                         'layer_1_46_1',
#                         'layer_1_47_1',
#                         'layer_1_48_1',
#                         'layer_1_49_1',
#                         'layer_1_50_1',
#                         'layer_1_51_1',
#                         'layer_1_52_1',
#                         'layer_1_53_1',
#                         'layer_1_54_1',
#                         'layer_1_55_1',
#                         'layer_1_56_1',
#                         'layer_1_57_1',
#                         'layer_1_58_1',
#                         'layer_1_59_1',
#                         'layer_1_60_1'],
#              'feeds_into': ['layer_3_1_1', 'layer_3_1_2'],
#              'layer_id': 'layer_2_3_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 30000.0}],
#                        'limit': [{'type': 'fixed amount',
#                                   'value': 3000000.0}]}},
#             {'covers': ['layer_1_61_1',
#                         'layer_1_62_1',
#                         'layer_1_63_1',
#                         'layer_1_64_1',
#                         'layer_1_65_1',
#                         'layer_1_66_1',
#                         'layer_1_67_1',
#                         'layer_1_68_1',
#                         'layer_1_69_1',
#                         'layer_1_70_1',
#                         'layer_1_71_1',
#                         'layer_1_72_1',
#                         'layer_1_73_1',
#                         'layer_1_74_1',
#                         'layer_1_75_1',
#                         'layer_1_76_1',
#                         'layer_1_77_1',
#                         'layer_1_78_1',
#                         'layer_1_79_1',
#                         'layer_1_80_1'],
#              'feeds_into': ['layer_3_1_1', 'layer_3_1_2'],
#              'layer_id': 'layer_2_4_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 40000.0}],
#                        'limit': [{'type': 'fixed amount',
#                                   'value': 4000000.0}]}},
#             {'covers': ['layer_1_81_1',
#                         'layer_1_82_1',
#                         'layer_1_83_1',
#                         'layer_1_84_1',
#                         'layer_1_86_1',
#                         'layer_1_87_1',
#                         'InsObj_1_85',
#                         'InsObj_1_88',
#                         'InsObj_1_89'],
#              'feeds_into': ['layer_3_1_1', 'layer_3_1_2'],
#              'layer_id': 'layer_2_5_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 50000.0}],
#                        'limit': [{'type': 'fixed amount',
#                                   'value': 5000000.0}]}},
#             {'covers': ['layer_2_1_1',
#                         'layer_2_2_1',
#                         'layer_2_3_1',
#                         'layer_2_4_1',
#                         'layer_2_5_1'],
#              'feeds_into': ['policy_loss'],
#              'layer_id': 'layer_3_1_1',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 10000.0}],
#                        'limit': [{'type': 'fixed amount', 'value': 20000000.0}],
#                        'share': {'type': '% of limit', 'value': 0.15}}},
#             {'covers': ['layer_2_1_1',
#                         'layer_2_2_1',
#                         'layer_2_3_1',
#                         'layer_2_4_1',
#                         'layer_2_5_1'],
#              'feeds_into': ['policy_loss'],
#              'layer_id': 'layer_3_1_2',
#              'terms': {'deductible': [{'type': 'fixed amount',
#                                        'value': 3000.0}],
#                        'limit': [{'type': 'fixed amount', 'value': 7000000.0}],
#                        'share': {'type': '% of limit', 'value': 0.25}}}]}

# %%
def node_layout(layer):

# %%
#def policy_structure(policy):
dot = Digraph(comment='Policy')

for layer in policy["layers"]:
    dot.attr("node", shape="rectangle")
    dot.node(layer["layer_id"], str(layer["terms"]))
    for cov in layer["covers"]:
        dot.attr("node", shape="circle")
        if cov.startswith("InsObj"):
            dot.node(cov, cov)
        
for layer in policy["layers"]:
    for cov in layer["covers"]:
        dot.edge(cov, layer["layer_id"])
    if "policy_loss" in layer["feeds_into"]:
        print(layer["layer_id"])
        dot.edge(layer["layer_id"], "policy_loss")
# Out:
# layer_3_1_1
# layer_3_1_2

# %%
dot.attr(rankdir="BT")
dot
